# %% [markdown]
# # Exploring player groupings using K-means for 2017/18 season

# %% [markdown]
# ## Purpose

# %% [markdown]
# The purpose of this notebook is to:
#
# - Create a complete dataset for all stats for all players in the Premier League in 2017/18 season
# 	- Potentially create a process for combining all datasets from the same source into a complete dataset for each year
# - Investigate and see if there are any logical groupings/cluster present based solely on the data (excluding assigned position and team)
# - Investigate the similarities between the players in each cluster

# %% [markdown]
# ## Data sources

# %% [markdown]
# - [Standard Stats](https://fbref.com/en/comps/9/2017-2018/stats/2017-2018-Premier-League-Stats)
# - [Goalkeeping Stats](https://fbref.com/en/comps/9/2017-2018/keepers/2017-2018-Premier-League-Stats)
# - [Shooting Stats](https://fbref.com/en/comps/9/2017-2018/shooting/2017-2018-Premier-League-Stats)
# - [Passing Stats](https://fbref.com/en/comps/9/2017-2018/passing/2017-2018-Premier-League-Stats)
# - [Defensive Stats](https://fbref.com/en/comps/9/2017-2018/defense/2017-2018-Premier-League-Stats)
# - [Possession Stats](https://fbref.com/en/comps/9/2017-2018/possession/2017-2018-Premier-League-Stats)

# %% [markdown]
# ## Method

# %% [markdown]
# ### Import relevant packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# ## Import relevant datasets

# %%
goalkeeping = pd.read_csv("../historic_player_stats/2017-2018/goalkeeping.csv")
defensive_actions = pd.read_csv("../historic_player_stats/2017-2018/defensive_actions.csv")
passing = pd.read_csv("../historic_player_stats/2017-2018/passing.csv")
possession = pd.read_csv("../historic_player_stats/2017-2018/possession.csv")
shooting = pd.read_csv("../historic_player_stats/2017-2018/shooting.csv")
standard = pd.read_csv("../historic_player_stats/2017-2018/standard.csv")

# %%
standard.head()
# Out:
#                 player position            team  matches_played  starts  \
# 0  Patrick van Aanholt       DF  Crystal Palace              28      25
# 1       Rolando Aarons    MF,FW   Newcastle Utd               4       1
# 2        Tammy Abraham       FW    Swansea City              31      15
# 3         Charlie Adam       MF      Stoke City              11       5
# 4               Adrián       GK        West Ham              19      19
#
#    minutes_played   90s  goals  assists  goals+assists  ...  \
# 0            2184  24.3      5        1              6  ...
# 1             139   1.5      0        0              0  ...
# 2            1726  19.2      5        1              6  ...
# 3             411   4.6      0        0              0  ...
# 4            1710  19.0      0        0              0  ...
#
#    penalties_attempted  yellow_cards  red_cards  expected_goals  \
# 0                    0             7          0             3.1
# 1                    0             0          0             0.1
# 2                    0             0          0             6.8
# 3                    1             2          1             1.6
# 4                    0             2          0             0.0
#
#    non_penalty_expected_goals  expected_assisted_goals  \
# 0                         3.1                      2.1
# 1                         0.1                      0.0
# 2                         6.8                      1.6
# 3                         0.9                      1.2
# 4                         0.0                      0.0
#
#    non_penalty_expected_goals+expected_assisted_goals  progressive_carries  \
# 0                                                5.2                  46.0
# 1                                                0.1                   7.0
# 2                                                8.4                  19.0
# 3                                                2.1                   6.0
# 4                                                0.0                   0.0
#
#    progressive_passes  progressive_passes_recieved
# 0                92.0                         86.0
# 1                 3.0                          4.0
# 2                20.0                        104.0
# 3                30.0                          9.0
# 4                 0.0                          0.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Join select dataframes into one (all bar goalkeeping)

# %%
complete = standard.merge(passing, on=["player", "position", "team"], how='inner')
complete = complete.merge(shooting, on=["player", "position", "team"], how='inner')
complete = complete.merge(possession, on=["player", "position", "team"], how='inner')
complete = complete.merge(defensive_actions, on=["player", "position", "team"], how='inner')

print("New dataframe dimensions: " + str(complete.shape))
# Out:
# New dataframe dimensions: (529, 79)

# %%
complete.head()
# Out:
#                 player position            team  matches_played  starts  \
# 0  Patrick van Aanholt       DF  Crystal Palace              28      25
# 1       Rolando Aarons    MF,FW   Newcastle Utd               4       1
# 2        Tammy Abraham       FW    Swansea City              31      15
# 3         Charlie Adam       MF      Stoke City              11       5
# 4               Adrián       GK        West Ham              19      19
#
#    minutes_played   90s  goals_x  assists  goals+assists  ...  \
# 0            2184  24.3        5        1              6  ...
# 1             139   1.5        0        0              0  ...
# 2            1726  19.2        5        1              6  ...
# 3             411   4.6        0        0              0  ...
# 4            1710  19.0        0        0              0  ...
#
#    defensive_third_tackles  middle_third_tackles  attacking_third_tackles  \
# 0                     29.0                  15.0                      3.0
# 1                      3.0                   1.0                      0.0
# 2                      1.0                   7.0                      2.0
# 3                      2.0                   5.0                      2.0
# 4                      2.0                   0.0                      0.0
#
#    dribblers_tackled  dribbler_tackles_attempted  shots_blocked  \
# 0               16.0                        34.0            5.0
# 1                4.0                         6.0            0.0
# 2                1.0                        13.0            1.0
# 3                5.0                        17.0            0.0
# 4                1.0                         4.0            0.0
#
#    passes_blocked  interceptions  clearances  errors_leading_to_shot
# 0            19.0           47.0        64.0                     2.0
# 1             3.0            1.0         0.0                     0.0
# 2             7.0            1.0        11.0                     0.0
# 3             2.0            9.0        11.0                     2.0
# 4             1.0            0.0        15.0                     1.0
#
# [5 rows x 79 columns]

# %% [markdown]
# ## Remove columns with operations

# %% [markdown]
# To reduce the number of features shown in the table originally. As these columns are generated with dta available in the table, they are not initially required, and can be recreated if required

# %%
operation_characters = set("/-+*")
columns_to_remove = [col for col in complete.columns if any(char in col for char in operation_characters)]

complete_without_calculated_columns = complete.drop(columns=columns_to_remove)

print(f"Number of Features reduced from {str(len(complete.columns))} to {str(len(complete_without_calculated_columns.columns))}")
print("\nFeatures removed:\n")
print("\n".join(columns_to_remove))
# Out:
# Number of Features reduced from 79 to 71
#
# Features removed:
#
# goals+assists
# non_penalty_expected_goals+expected_assisted_goals
# assists-expected_assisted_goals
# goals/shots
# goals/shots_on_target
# non_penalty_expected_goals/shots
# goals-expected_goals
# non_penalty_goals-non_penalty_expected_goals

# %% [markdown]
# ## EDA

# %%
complete_without_calculated_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529 entries, 0 to 528
# Data columns (total 71 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   player                              529 non-null    object
#  1   position                            529 non-null    object
#  2   team                                529 non-null    object
#  3   matches_played                      529 non-null    int64
#  4   starts                              529 non-null    int64
#  5   minutes_played                      529 non-null    int64
#  6   90s                                 529 non-null    float64
#  7   goals_x                             529 non-null    int64
#  8   assists                             529 non-null    int64
#  9   non_penalty_goals                   529 non-null    int64
#  10  penalties_scored                    529 non-null    int64
#  11  penalties_attempted                 529 non-null    int64
#  12  yellow_cards                        529 non-null    int64
#  13  red_cards                           529 non-null    int64
#  14  expected_goals                      528 non-null    float64
#  15  non_penalty_expected_goals          528 non-null    float64
#  16  expected_assisted_goals_x           528 non-null    float64
#  17  progressive_carries                 528 non-null    float64
#  18  progressive_passes_x                528 non-null    float64
#  19  progressive_passes_recieved         528 non-null    float64
#  20  total_passing_distance              528 non-null    float64
#  21  total_progressive_passing_distance  528 non-null    float64
#  22  short_passes_completed              528 non-null    float64
#  23  short_passes_attempted              528 non-null    float64
#  24  medium_passes_completed             528 non-null    float64
#  25  medium_passes_attempted             528 non-null    float64
#  26  long_passes_completed               528 non-null    float64
#  27  long_passes_attempted               528 non-null    float64
#  28  expected_assisted_goals_y           528 non-null    float64
#  29  expected_assists                    528 non-null    float64
#  30  key_passes                          528 non-null    float64
#  31  passes_into_final_third             528 non-null    float64
#  32  passes_into_penalty_area            528 non-null    float64
#  33  crosses_into_penalty_area           528 non-null    float64
#  34  progressive_passes_y                528 non-null    float64
#  35  goals_y                             529 non-null    int64
#  36  shots                               528 non-null    float64
#  37  shots_on_target                     529 non-null    int64
#  38  average_shot_distance               441 non-null    float64
#  39  shots_from_free_kicks               528 non-null    float64
#  40  shots_from_penalties                529 non-null    int64
#  41  touches                             528 non-null    float64
#  42  touches_in_defensive_penalty_area   528 non-null    float64
#  43  touches_in_defensive_third          528 non-null    float64
#  44  touches_in_middle_third             528 non-null    float64
#  45  touches_in_attacking_third          528 non-null    float64
#  46  touches_in_attacking_penalty_area   528 non-null    float64
#  47  live_ball_touches                   528 non-null    float64
#  48  take_ons_attempted                  528 non-null    float64
#  49  take_ons_succeeded                  528 non-null    float64
#  50  times_tackled_during_take_on        528 non-null    float64
#  51  carries                             528 non-null    float64
#  52  total_carrying_distance             528 non-null    float64
#  53  progressive_carrying_distance       528 non-null    float64
#  54  carries_into_final_third            528 non-null    float64
#  55  carries_into_penalty_area           528 non-null    float64
#  56  miscontrols                         528 non-null    float64
#  57  dispossessed                        528 non-null    float64
#  58  passes_received                     528 non-null    float64
#  59  tackles                             528 non-null    float64
#  60  tackles_won                         528 non-null    float64
#  61  defensive_third_tackles             528 non-null    float64
#  62  middle_third_tackles                528 non-null    float64
#  63  attacking_third_tackles             528 non-null    float64
#  64  dribblers_tackled                   528 non-null    float64
#  65  dribbler_tackles_attempted          528 non-null    float64
#  66  shots_blocked                       528 non-null    float64
#  67  passes_blocked                      528 non-null    float64
#  68  interceptions                       528 non-null    float64
#  69  clearances                          528 non-null    float64
#  70  errors_leading_to_shot              528 non-null    float64
# dtypes: float64(55), int64(13), object(3)
# memory usage: 293.6+ KB

# %% [markdown]
# ### Remove duplicated columns

# %% [markdown]
# Seeing two goals columns, make sure the are the same before dropping one

# %%
complete_without_calculated_columns[["goals_x", "goals_y"]][(complete_without_calculated_columns["goals_x"] != complete_without_calculated_columns["goals_y"])]
# Out:
# Empty DataFrame
# Columns: [goals_x, goals_y]
# Index: []

# %%
complete_without_calculated_columns[["expected_assisted_goals_x", "expected_assisted_goals_y"]][(complete_without_calculated_columns["expected_assisted_goals_x"] != complete_without_calculated_columns["expected_assisted_goals_y"])]
# Out:
#      expected_assisted_goals_x  expected_assisted_goals_y
# 363                        NaN                        NaN

# %%
complete_without_calculated_columns[["progressive_passes_x", "progressive_passes_y"]][(complete_without_calculated_columns["progressive_passes_x"] != complete_without_calculated_columns["progressive_passes_y"])]
# Out:
#      progressive_passes_x  progressive_passes_y
# 363                   NaN                   NaN

# %% [markdown]
# The above shows the contents of the two columns are the same, as there are no rows where the are not identical; one of them can be dropped and the other renamed to remove the suffix, along with those for the expected_assisted_goals and progressive_passes columns

# %%
complete_without_calculated_columns = complete_without_calculated_columns.drop(columns=["goals_y", "expected_assisted_goals_y", "progressive_passes_y"])
complete_without_calculated_columns = complete_without_calculated_columns.rename(columns={"goals_x": "goals", "expected_assisted_goals_x": "expected_assisted_goals", "progressive_passes_x": "progressive_passes"})
complete_without_calculated_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 529 entries, 0 to 528
# Data columns (total 68 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   player                              529 non-null    object
#  1   position                            529 non-null    object
#  2   team                                529 non-null    object
#  3   matches_played                      529 non-null    int64
#  4   starts                              529 non-null    int64
#  5   minutes_played                      529 non-null    int64
#  6   90s                                 529 non-null    float64
#  7   goals                               529 non-null    int64
#  8   assists                             529 non-null    int64
#  9   non_penalty_goals                   529 non-null    int64
#  10  penalties_scored                    529 non-null    int64
#  11  penalties_attempted                 529 non-null    int64
#  12  yellow_cards                        529 non-null    int64
#  13  red_cards                           529 non-null    int64
#  14  expected_goals                      528 non-null    float64
#  15  non_penalty_expected_goals          528 non-null    float64
#  16  expected_assisted_goals             528 non-null    float64
#  17  progressive_carries                 528 non-null    float64
#  18  progressive_passes                  528 non-null    float64
#  19  progressive_passes_recieved         528 non-null    float64
#  20  total_passing_distance              528 non-null    float64
#  21  total_progressive_passing_distance  528 non-null    float64
#  22  short_passes_completed              528 non-null    float64
#  23  short_passes_attempted              528 non-null    float64
#  24  medium_passes_completed             528 non-null    float64
#  25  medium_passes_attempted             528 non-null    float64
#  26  long_passes_completed               528 non-null    float64
#  27  long_passes_attempted               528 non-null    float64
#  28  expected_assists                    528 non-null    float64
#  29  key_passes                          528 non-null    float64
#  30  passes_into_final_third             528 non-null    float64
#  31  passes_into_penalty_area            528 non-null    float64
#  32  crosses_into_penalty_area           528 non-null    float64
#  33  shots                               528 non-null    float64
#  34  shots_on_target                     529 non-null    int64
#  35  average_shot_distance               441 non-null    float64
#  36  shots_from_free_kicks               528 non-null    float64
#  37  shots_from_penalties                529 non-null    int64
#  38  touches                             528 non-null    float64
#  39  touches_in_defensive_penalty_area   528 non-null    float64
#  40  touches_in_defensive_third          528 non-null    float64
#  41  touches_in_middle_third             528 non-null    float64
#  42  touches_in_attacking_third          528 non-null    float64
#  43  touches_in_attacking_penalty_area   528 non-null    float64
#  44  live_ball_touches                   528 non-null    float64
#  45  take_ons_attempted                  528 non-null    float64
#  46  take_ons_succeeded                  528 non-null    float64
#  47  times_tackled_during_take_on        528 non-null    float64
#  48  carries                             528 non-null    float64
#  49  total_carrying_distance             528 non-null    float64
#  50  progressive_carrying_distance       528 non-null    float64
#  51  carries_into_final_third            528 non-null    float64
#  52  carries_into_penalty_area           528 non-null    float64
#  53  miscontrols                         528 non-null    float64
#  54  dispossessed                        528 non-null    float64
#  55  passes_received                     528 non-null    float64
#  56  tackles                             528 non-null    float64
#  57  tackles_won                         528 non-null    float64
#  58  defensive_third_tackles             528 non-null    float64
#  59  middle_third_tackles                528 non-null    float64
#  60  attacking_third_tackles             528 non-null    float64
#  61  dribblers_tackled                   528 non-null    float64
#  62  dribbler_tackles_attempted          528 non-null    float64
#  63  shots_blocked                       528 non-null    float64
#  64  passes_blocked                      528 non-null    float64
#  65  interceptions                       528 non-null    float64
#  66  clearances                          528 non-null    float64
#  67  errors_leading_to_shot              528 non-null    float64
# dtypes: float64(53), int64(12), object(3)
# memory usage: 281.2+ KB

# %% [markdown]
# ### Missing values

# %%
complete_without_calculated_columns.isnull().sum()[complete_without_calculated_columns.isnull().sum() > 0]
# Out:
# expected_goals                         1
# non_penalty_expected_goals             1
# expected_assisted_goals                1
# progressive_carries                    1
# progressive_passes                     1
# progressive_passes_recieved            1
# total_passing_distance                 1
# total_progressive_passing_distance     1
# short_passes_completed                 1
# short_passes_attempted                 1
# medium_passes_completed                1
# medium_passes_attempted                1
# long_passes_completed                  1
# long_passes_attempted                  1
# expected_assists                       1
# key_passes                             1
# passes_into_final_third                1
# passes_into_penalty_area               1
# crosses_into_penalty_area              1
# shots                                  1
# average_shot_distance                 88
# shots_from_free_kicks                  1
# touches                                1
# touches_in_defensive_penalty_area      1
# touches_in_defensive_third             1
# touches_in_middle_third                1
# touches_in_attacking_third             1
# touches_in_attacking_penalty_area      1
# live_ball_touches                      1
# take_ons_attempted                     1
# take_ons_succeeded                     1
# times_tackled_during_take_on           1
# carries                                1
# total_carrying_distance                1
# progressive_carrying_distance          1
# carries_into_final_third               1
# carries_into_penalty_area              1
# miscontrols                            1
# dispossessed                           1
# passes_received                        1
# tackles                                1
# tackles_won                            1
# defensive_third_tackles                1
# middle_third_tackles                   1
# attacking_third_tackles                1
# dribblers_tackled                      1
# dribbler_tackles_attempted             1
# shots_blocked                          1
# passes_blocked                         1
# interceptions                          1
# clearances                             1
# errors_leading_to_shot                 1
# dtype: int64

# %% [markdown]
# Average shot distance seems to contain the majority of null values present in the table

# %%
pd.set_option("display.max_columns", None)
complete_without_calculated_columns[complete_without_calculated_columns.isnull().any(axis=1)]
# Out:
#                  player position            team  matches_played  starts  \
# 4                Adrián       GK        West Ham              19      19
# 5       Ibrahim Afellay       MF      Stoke City               6       1
# 15       Daniel Amartey       DF  Leicester City               8       6
# 16         Ethan Ampadu       DF         Chelsea               1       0
# 33          Sam Baldock       FW        Brighton               2       0
# ..                  ...      ...             ...             ...     ...
# 495  Kyle Walker-Peters       DF       Tottenham               3       2
# 497   Aaron Wan-Bissaka       DF  Crystal Palace               7       7
# 506      Dean Whitehead       MF    Huddersfield               4       0
# 517        Ben Woodburn       FW       Liverpool               1       0
# 526    Marvin Zeegelaar       DF         Watford              12      12
#
#      minutes_played   90s  goals  assists  non_penalty_goals  \
# 4              1710  19.0      0        0                  0
# 5               166   1.8      0        0                  0
# 15              487   5.4      0        0                  0
# 16               11   0.1      0        0                  0
# 33               32   0.4      0        0                  0
# ..              ...   ...    ...      ...                ...
# 495             189   2.1      0        2                  0
# 497             627   7.0      0        0                  0
# 506              71   0.8      0        0                  0
# 517               7   0.1      0        0                  0
# 526             994  11.0      0        1                  0
#
#      penalties_scored  penalties_attempted  yellow_cards  red_cards  \
# 4                   0                    0             2          0
# 5                   0                    0             1          0
# 15                  0                    0             1          2
# 16                  0                    0             0          0
# 33                  0                    0             0          0
# ..                ...                  ...           ...        ...
# 495                 0                    0             0          0
# 497                 0                    0             1          0
# 506                 0                    0             0          0
# 517                 0                    0             0          0
# 526                 0                    0             4          1
#
#      expected_goals  non_penalty_expected_goals  expected_assisted_goals  \
# 4               0.0                         0.0                      0.0
# 5               0.0                         0.0                      0.0
# 15              0.0                         0.0                      0.0
# 16              0.0                         0.0                      0.0
# 33              0.0                         0.0                      0.0
# ..              ...                         ...                      ...
# 495             0.0                         0.0                      1.2
# 497             0.0                         0.0                      0.2
# 506             0.0                         0.0                      0.0
# 517             0.0                         0.0                      0.0
# 526             0.0                         0.0                      1.0
#
#      progressive_carries  progressive_passes  progressive_passes_recieved  \
# 4                    0.0                 0.0                          0.0
# 5                    0.0                 4.0                          1.0
# 15                   5.0                14.0                          4.0
# 16                   0.0                 1.0                          0.0
# 33                   0.0                 0.0                          5.0
# ..                   ...                 ...                          ...
# 495                  8.0                 8.0                         21.0
# 497                 22.0                23.0                         14.0
# 506                  0.0                 1.0                          0.0
# 517                  0.0                 0.0                          2.0
# 526                 30.0                54.0                         44.0
#
#      total_passing_distance  total_progressive_passing_distance  \
# 4                   11798.0                             10438.0
# 5                    1326.0                               256.0
# 15                   3859.0                              1555.0
# 16                    391.0                               149.0
# 33                     41.0                                 7.0
# ..                      ...                                 ...
# 495                  1608.0                               479.0
# 497                  2676.0                              1448.0
# 506                   808.0                               221.0
# 517                    92.0                                11.0
# 526                  6677.0                              3045.0
#
#      short_passes_completed  short_passes_attempted  medium_passes_completed  \
# 4                      12.0                    12.0                     51.0
# 5                      29.0                    32.0                     35.0
# 15                    129.0                   142.0                     83.0
# 16                      5.0                     5.0                     13.0
# 33                      3.0                     5.0                      1.0
# ..                      ...                     ...                      ...
# 495                    56.0                    63.0                     35.0
# 497                   125.0                   150.0                     56.0
# 506                    15.0                    17.0                     25.0
# 517                     4.0                     4.0                      1.0
# 526                   259.0                   297.0                    140.0
#
#      medium_passes_attempted  long_passes_completed  long_passes_attempted  \
# 4                       52.0                  203.0                  503.0
# 5                       39.0                    6.0                    8.0
# 15                     109.0                   20.0                   45.0
# 16                      13.0                    1.0                    1.0
# 33                       2.0                    0.0                    0.0
# ..                       ...                    ...                    ...
# 495                     50.0                    9.0                   13.0
# 497                     89.0                    8.0                   33.0
# 506                     30.0                    3.0                    4.0
# 517                      1.0                    1.0                    1.0
# 526                    193.0                   28.0                   55.0
#
#      expected_assists  key_passes  passes_into_final_third  \
# 4                 0.1         0.0                     13.0
# 5                 0.0         0.0                      6.0
# 15                0.1         0.0                     14.0
# 16                0.0         0.0                      1.0
# 33                0.0         0.0                      0.0
# ..                ...         ...                      ...
# 495               1.0         3.0                      5.0
# 497               0.4         3.0                     12.0
# 506               0.0         0.0                      3.0
# 517               0.0         0.0                      0.0
# 526               0.8         7.0                     39.0
#
#      passes_into_penalty_area  crosses_into_penalty_area  shots  \
# 4                         1.0                        0.0    0.0
# 5                         0.0                        0.0    0.0
# 15                        0.0                        0.0    0.0
# 16                        0.0                        0.0    0.0
# 33                        0.0                        0.0    0.0
# ..                        ...                        ...    ...
# 495                       4.0                        2.0    0.0
# 497                       4.0                        3.0    0.0
# 506                       0.0                        0.0    0.0
# 517                       0.0                        0.0    0.0
# 526                      10.0                        7.0    0.0
#
#      shots_on_target  average_shot_distance  shots_from_free_kicks  \
# 4                  0                    NaN                    0.0
# 5                  0                    NaN                    0.0
# 15                 0                    NaN                    0.0
# 16                 0                    NaN                    0.0
# 33                 0                    NaN                    0.0
# ..               ...                    ...                    ...
# 495                0                    NaN                    0.0
# 497                0                    NaN                    0.0
# 506                0                    NaN                    0.0
# 517                0                    NaN                    0.0
# 526                0                    NaN                    0.0
#
#      shots_from_penalties  touches  touches_in_defensive_penalty_area  \
# 4                       0    641.0                              541.0
# 5                       0     89.0                                0.0
# 15                      0    362.0                               24.0
# 16                      0     22.0                                2.0
# 33                      0     10.0                                0.0
# ..                    ...      ...                                ...
# 495                     0    157.0                                7.0
# 497                     0    411.0                               45.0
# 506                     0     54.0                                1.0
# 517                     0      8.0                                0.0
# 526                     0    683.0                               35.0
#
#      touches_in_defensive_third  touches_in_middle_third  \
# 4                         633.0                      9.0
# 5                          18.0                     63.0
# 15                        129.0                    189.0
# 16                          9.0                     13.0
# 33                          0.0                      3.0
# ..                          ...                      ...
# 495                        43.0                     62.0
# 497                       169.0                    154.0
# 506                        19.0                     34.0
# 517                         0.0                      3.0
# 526                       181.0                    317.0
#
#      touches_in_attacking_third  touches_in_attacking_penalty_area  \
# 4                           0.0                                0.0
# 5                          12.0                                0.0
# 15                         46.0                                0.0
# 16                          0.0                                0.0
# 33                          7.0                                3.0
# ..                          ...                                ...
# 495                        55.0                                4.0
# 497                        93.0                                1.0
# 506                         1.0                                0.0
# 517                         5.0                                1.0
# 526                       191.0                               12.0
#
#      live_ball_touches  take_ons_attempted  take_ons_succeeded  \
# 4                641.0                 0.0                 0.0
# 5                 89.0                 1.0                 1.0
# 15               362.0                 5.0                 4.0
# 16                22.0                 0.0                 0.0
# 33                10.0                 1.0                 0.0
# ..                 ...                 ...                 ...
# 495              157.0                 8.0                 4.0
# 497              411.0                15.0                13.0
# 506               54.0                 0.0                 0.0
# 517                8.0                 0.0                 0.0
# 526              683.0                20.0                15.0
#
#      times_tackled_during_take_on  carries  total_carrying_distance  \
# 4                             0.0    284.0                   2193.0
# 5                             0.0     61.0                    214.0
# 15                            1.0    157.0                    858.0
# 16                            0.0     16.0                     62.0
# 33                            1.0      6.0                     11.0
# ..                            ...      ...                      ...
# 495                           4.0     84.0                    433.0
# 497                           2.0    175.0                    997.0
# 506                           0.0     37.0                    163.0
# 517                           0.0      6.0                     15.0
# 526                           5.0    327.0                   1608.0
#
#      progressive_carrying_distance  carries_into_final_third  \
# 4                           1505.0                       0.0
# 5                             50.0                       0.0
# 15                           432.0                       6.0
# 16                            33.0                       0.0
# 33                             1.0                       0.0
# ..                             ...                       ...
# 495                          207.0                       5.0
# 497                          623.0                      22.0
# 506                           60.0                       0.0
# 517                            5.0                       2.0
# 526                          813.0                      11.0
#
#      carries_into_penalty_area  miscontrols  dispossessed  passes_received  \
# 4                          0.0          0.0           0.0            166.0
# 5                          0.0          1.0           3.0             64.0
# 15                         0.0          3.0           4.0            192.0
# 16                         0.0          0.0           0.0             19.0
# 33                         0.0          2.0           1.0             10.0
# ..                         ...          ...           ...              ...
# 495                        1.0          3.0           5.0             99.0
# 497                        1.0          9.0           6.0            168.0
# 506                        0.0          0.0           0.0             41.0
# 517                        0.0          0.0           0.0              8.0
# 526                        2.0         11.0          10.0            347.0
#
#      tackles  tackles_won  defensive_third_tackles  middle_third_tackles  \
# 4        2.0          1.0                      2.0                   0.0
# 5        3.0          3.0                      0.0                   3.0
# 15       8.0          4.0                      7.0                   1.0
# 16       1.0          1.0                      0.0                   1.0
# 33       0.0          0.0                      0.0                   0.0
# ..       ...          ...                      ...                   ...
# 495      5.0          4.0                      4.0                   1.0
# 497     30.0         19.0                     20.0                   7.0
# 506      0.0          0.0                      0.0                   0.0
# 517      0.0          0.0                      0.0                   0.0
# 526     23.0         18.0                     15.0                   3.0
#
#      attacking_third_tackles  dribblers_tackled  dribbler_tackles_attempted  \
# 4                        0.0                1.0                         4.0
# 5                        0.0                1.0                         2.0
# 15                       0.0                3.0                         7.0
# 16                       0.0                0.0                         0.0
# 33                       0.0                0.0                         0.0
# ..                       ...                ...                         ...
# 495                      0.0                2.0                         4.0
# 497                      3.0               15.0                        19.0
# 506                      0.0                0.0                         1.0
# 517                      0.0                0.0                         0.0
# 526                      5.0               11.0                        24.0
#
#      shots_blocked  passes_blocked  interceptions  clearances  \
# 4              0.0             1.0            0.0        15.0
# 5              0.0             1.0            1.0         1.0
# 15             3.0             4.0            7.0        21.0
# 16             0.0             0.0            0.0         2.0
# 33             0.0             0.0            0.0         0.0
# ..             ...             ...            ...         ...
# 495            0.0             2.0            3.0         8.0
# 497            7.0            11.0           15.0        45.0
# 506            0.0             1.0            2.0         0.0
# 517            0.0             0.0            0.0         0.0
# 526            1.0             4.0           20.0        30.0
#
#      errors_leading_to_shot
# 4                       1.0
# 5                       0.0
# 15                      1.0
# 16                      0.0
# 33                      0.0
# ..                      ...
# 495                     0.0
# 497                     0.0
# 506                     0.0
# 517                     0.0
# 526                     0.0
#
# [88 rows x 68 columns]

# %%
complete_without_calculated_columns[["shots", "shots_on_target", "average_shot_distance"]][(complete_without_calculated_columns["shots"] != 0) & (complete_without_calculated_columns["average_shot_distance"].isnull())]
# Out:
#      shots  shots_on_target  average_shot_distance
# 363    NaN                0                    NaN

# %%
complete_without_calculated_columns[["shots", "shots_on_target", "average_shot_distance"]][(complete_without_calculated_columns["shots"] == 0) & (complete_without_calculated_columns["average_shot_distance"].isnull())]
# Out:
#      shots  shots_on_target  average_shot_distance
# 4      0.0                0                    NaN
# 5      0.0                0                    NaN
# 15     0.0                0                    NaN
# 16     0.0                0                    NaN
# 33     0.0                0                    NaN
# ..     ...              ...                    ...
# 495    0.0                0                    NaN
# 497    0.0                0                    NaN
# 506    0.0                0                    NaN
# 517    0.0                0                    NaN
# 526    0.0                0                    NaN
#
# [87 rows x 3 columns]

# %% [markdown]
# On closer inspection, this occur when the number of shots taken by a player is 0, so this may be the only way to display this value. Setting this value to 0 would indicate that these players are taking shots from 0 yards away from the goal, which is not accurate, and an arbitrarily high number may also adversely affect the conclusions pulled from the data.

# %% [markdown]
# Setting to 0, however, may be the only viable option in this position

# %%
complete_without_calculated_columns["average_shot_distance"] = complete_without_calculated_columns["average_shot_distance"].fillna(0)

# %%
complete_without_calculated_columns[complete_without_calculated_columns.isnull().any(axis=1)]
# Out:
#             player position     team  matches_played  starts  minutes_played  \
# 363  Aiden O'Neill       MF  Burnley               1       0               1
#
#      90s  goals  assists  non_penalty_goals  penalties_scored  \
# 363  0.0      0        0                  0                 0
#
#      penalties_attempted  yellow_cards  red_cards  expected_goals  \
# 363                    0             0          0             NaN
#
#      non_penalty_expected_goals  expected_assisted_goals  progressive_carries  \
# 363                         NaN                      NaN                  NaN
#
#      progressive_passes  progressive_passes_recieved  total_passing_distance  \
# 363                 NaN                          NaN                     NaN
#
#      total_progressive_passing_distance  short_passes_completed  \
# 363                                 NaN                     NaN
#
#      short_passes_attempted  medium_passes_completed  medium_passes_attempted  \
# 363                     NaN                      NaN                      NaN
#
#      long_passes_completed  long_passes_attempted  expected_assists  \
# 363                    NaN                    NaN               NaN
#
#      key_passes  passes_into_final_third  passes_into_penalty_area  \
# 363         NaN                      NaN                       NaN
#
#      crosses_into_penalty_area  shots  shots_on_target  average_shot_distance  \
# 363                        NaN    NaN                0                    0.0
#
#      shots_from_free_kicks  shots_from_penalties  touches  \
# 363                    NaN                     0      NaN
#
#      touches_in_defensive_penalty_area  touches_in_defensive_third  \
# 363                                NaN                         NaN
#
#      touches_in_middle_third  touches_in_attacking_third  \
# 363                      NaN                         NaN
#
#      touches_in_attacking_penalty_area  live_ball_touches  take_ons_attempted  \
# 363                                NaN                NaN                 NaN
#
#      take_ons_succeeded  times_tackled_during_take_on  carries  \
# 363                 NaN                           NaN      NaN
#
#      total_carrying_distance  progressive_carrying_distance  \
# 363                      NaN                            NaN
#
#      carries_into_final_third  carries_into_penalty_area  miscontrols  \
# 363                       NaN                        NaN          NaN
#
#      dispossessed  passes_received  tackles  tackles_won  \
# 363           NaN              NaN      NaN          NaN
#
#      defensive_third_tackles  middle_third_tackles  attacking_third_tackles  \
# 363                      NaN                   NaN                      NaN
#
#      dribblers_tackled  dribbler_tackles_attempted  shots_blocked  \
# 363                NaN                         NaN            NaN
#
#      passes_blocked  interceptions  clearances  errors_leading_to_shot
# 363             NaN            NaN         NaN                     NaN

# %% [markdown]
# The final null values shown in the table are all from the above entry from **Aiden O'Neill**, who played one minute the whole season, and therefore has no entries for many of the values in the table. In this case, and only this one, the row will be dropped, as it does not contain any useful important information, and it could be said that this player had no effect on the Burnley team through the season. It would also be very hard to group this palyer with others as the amount of data present on this player is not enough to come to any conclusions

# %%
complete_no_nulls = complete_without_calculated_columns[complete_without_calculated_columns["player"] != "Aiden O'Neill"]

# %%
complete_no_nulls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 528 entries, 0 to 528
# Data columns (total 68 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   player                              528 non-null    object
#  1   position                            528 non-null    object
#  2   team                                528 non-null    object
#  3   matches_played                      528 non-null    int64
#  4   starts                              528 non-null    int64
#  5   minutes_played                      528 non-null    int64
#  6   90s                                 528 non-null    float64
#  7   goals                               528 non-null    int64
#  8   assists                             528 non-null    int64
#  9   non_penalty_goals                   528 non-null    int64
#  10  penalties_scored                    528 non-null    int64
#  11  penalties_attempted                 528 non-null    int64
#  12  yellow_cards                        528 non-null    int64
#  13  red_cards                           528 non-null    int64
#  14  expected_goals                      528 non-null    float64
#  15  non_penalty_expected_goals          528 non-null    float64
#  16  expected_assisted_goals             528 non-null    float64
#  17  progressive_carries                 528 non-null    float64
#  18  progressive_passes                  528 non-null    float64
#  19  progressive_passes_recieved         528 non-null    float64
#  20  total_passing_distance              528 non-null    float64
#  21  total_progressive_passing_distance  528 non-null    float64
#  22  short_passes_completed              528 non-null    float64
#  23  short_passes_attempted              528 non-null    float64
#  24  medium_passes_completed             528 non-null    float64
#  25  medium_passes_attempted             528 non-null    float64
#  26  long_passes_completed               528 non-null    float64
#  27  long_passes_attempted               528 non-null    float64
#  28  expected_assists                    528 non-null    float64
#  29  key_passes                          528 non-null    float64
#  30  passes_into_final_third             528 non-null    float64
#  31  passes_into_penalty_area            528 non-null    float64
#  32  crosses_into_penalty_area           528 non-null    float64
#  33  shots                               528 non-null    float64
#  34  shots_on_target                     528 non-null    int64
#  35  average_shot_distance               528 non-null    float64
#  36  shots_from_free_kicks               528 non-null    float64
#  37  shots_from_penalties                528 non-null    int64
#  38  touches                             528 non-null    float64
#  39  touches_in_defensive_penalty_area   528 non-null    float64
#  40  touches_in_defensive_third          528 non-null    float64
#  41  touches_in_middle_third             528 non-null    float64
#  42  touches_in_attacking_third          528 non-null    float64
#  43  touches_in_attacking_penalty_area   528 non-null    float64
#  44  live_ball_touches                   528 non-null    float64
#  45  take_ons_attempted                  528 non-null    float64
#  46  take_ons_succeeded                  528 non-null    float64
#  47  times_tackled_during_take_on        528 non-null    float64
#  48  carries                             528 non-null    float64
#  49  total_carrying_distance             528 non-null    float64
#  50  progressive_carrying_distance       528 non-null    float64
#  51  carries_into_final_third            528 non-null    float64
#  52  carries_into_penalty_area           528 non-null    float64
#  53  miscontrols                         528 non-null    float64
#  54  dispossessed                        528 non-null    float64
#  55  passes_received                     528 non-null    float64
#  56  tackles                             528 non-null    float64
#  57  tackles_won                         528 non-null    float64
#  58  defensive_third_tackles             528 non-null    float64
#  59  middle_third_tackles                528 non-null    float64
#  60  attacking_third_tackles             528 non-null    float64
#  61  dribblers_tackled                   528 non-null    float64
#  62  dribbler_tackles_attempted          528 non-null    float64
#  63  shots_blocked                       528 non-null    float64
#  64  passes_blocked                      528 non-null    float64
#  65  interceptions                       528 non-null    float64
#  66  clearances                          528 non-null    float64
#  67  errors_leading_to_shot              528 non-null    float64
# dtypes: float64(53), int64(12), object(3)
# memory usage: 284.6+ KB

# %% [markdown]
# ### Removing unnecessary columns

# %% [markdown]
# For the objective of this notebook, which to help to identify key cluster of players within the data
